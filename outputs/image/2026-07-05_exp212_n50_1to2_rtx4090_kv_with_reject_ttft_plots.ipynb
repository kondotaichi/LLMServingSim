# %% [markdown]
# # TTFT breakdown & CDF — 検証2-1-2(KVキャッシュ考慮, UE再送含む4手法)
#
# 読み込むCSV:
# - `results/exp212-1to2-nearest-kv.csv`
# - `results/exp212-1to2-nearest-reject.csv`
# - `results/exp212-1to2-nearest-migrate.csv`
# - `results/exp212-1to2-nearest-migrate-kv.csv`
#
# 出力画像:
# - `outputs/image/2026-07-05_exp212_n50_1to2_rtx4090_kv_with_reject_ttft_breakdown.png`
# - `outputs/image/2026-07-05_exp212_n50_1to2_rtx4090_kv_with_reject_ttft_cdf.png`

# %%
from pathlib import Path
from IPython.display import Image
REPO_ROOT = Path.cwd()
while not (REPO_ROOT / "outputs/image").exists():
    REPO_ROOT = REPO_ROOT.parent
Image(filename=str(REPO_ROOT / "outputs/image/2026-07-05_exp212_n50_1to2_rtx4090_kv_with_reject_ttft_breakdown.png"))

# %%
from IPython.display import Image
Image(filename=str(REPO_ROOT / "outputs/image/2026-07-05_exp212_n50_1to2_rtx4090_kv_with_reject_ttft_cdf.png"))
